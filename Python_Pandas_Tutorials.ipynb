# %%
import pandas as pd
import numpy as np

# %%
dict={
  "name":['Abhishek','Deepak','saket','yetendra','Kumari Shubham','Suman Som','Soham Biswas','Kiran Gajjana','Dorothy Barman','Sreyashi karmakar','Anurag Maurya','Bipal Khanal'],
  "city":['Bihar','Punjab','Bihar','gujarath','Bihar','westbengal','westbengal','Telangana','westbengal','westbengal','utharpradesh','Sikkim'],
  "cgpa":[8,6,9,8,6,7,7,7,7,7,7,8],
  "placemenet":['yes','yes','yes','yes','yes','no','yes','no','yes','yes','no','no']
}

# %%
data=pd.DataFrame(dict)

# %%
data.to_csv("nitsikkim.csv")

# %%
data1=pd.read_csv("/content/nitsikkim.csv",index_col=0)

# %%
data1
# Out:
#                  name          city  cgpa placemenet
# 0            Abhishek         Bihar     8        yes
# 1              Deepak        Punjab     6        yes
# 2               saket         Bihar     9        yes
# 3            yetendra      gujarath     8        yes
# 4      Kumari Shubham         Bihar     6        yes
# 5           Suman Som    westbengal     7         no
# 6        Soham Biswas    westbengal     7        yes
# 7       Kiran Gajjana     Telangana     7         no
# 8      Dorothy Barman    westbengal     7        yes
# 9   Sreyashi karmakar    westbengal     7        yes
# 10      Anurag Maurya  utharpradesh     7         no
# 11       Bipal Khanal        Sikkim     8         no

# %%
import seaborn as sns

# %%
from sklearn.compose import ColumnTransformer

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,StandardScaler

# %%
TRansformer=ColumnTransformer(transformers=[('trans1',OneHotEncoder(drop='first',sparse=False),['name']),
                                            ('trans2',OneHotEncoder(drop='first',sparse=False),['city']),
                                            ('trans3',StandardScaler(),['cgpa'])],remainder='passthrough')

# %%
x1=data1.iloc[:,0:1]

# %%
x=data1.iloc[:,0:3]

# %%
x
# Out:
#                  name          city  cgpa
# 0            Abhishek         Bihar     8
# 1              Deepak        Punjab     6
# 2               saket         Bihar     9
# 3            yetendra      gujarath     8
# 4      Kumari Shubham         Bihar     6
# 5           Suman Som    westbengal     7
# 6        Soham Biswas    westbengal     7
# 7       Kiran Gajjana     Telangana     7
# 8      Dorothy Barman    westbengal     7
# 9   Sreyashi karmakar    westbengal     7
# 10      Anurag Maurya  utharpradesh     7
# 11       Bipal Khanal        Sikkim     8

# %%
y=data1.iloc[:,-1]

# %%
y
# Out:
# 0     yes
# 1     yes
# 2     yes
# 3     yes
# 4     yes
# 5      no
# 6     yes
# 7      no
# 8     yes
# 9     yes
# 10     no
# 11     no
# Name: placemenet, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train_transformed=TRansformer.fit_transform(x_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
x_train_transformed.shape
# Out:
# (10, 14)

# %%
data1['new_data'] = np.where(data1['city'].isin(['Telangana']), 1, 0)

# %%
data1
# Out:
#                  name          city  cgpa placemenet  new_data
# 0            Abhishek         Bihar     8        yes         0
# 1              Deepak        Punjab     6        yes         0
# 2               saket         Bihar     9        yes         0
# 3            yetendra      gujarath     8        yes         0
# 4      Kumari Shubham         Bihar     6        yes         0
# 5           Suman Som    westbengal     7         no         0
# 6        Soham Biswas    westbengal     7        yes         0
# 7       Kiran Gajjana     Telangana     7         no         1
# 8      Dorothy Barman    westbengal     7        yes         0
# 9   Sreyashi karmakar    westbengal     7        yes         0
# 10      Anurag Maurya  utharpradesh     7         no         0
# 11       Bipal Khanal        Sikkim     8         no         0

# %%
data1.to_string()
# Out:
# '                 name          city  cgpa placemenet\n0            Abhishek         Bihar     8        yes\n1              Deepak        Punjab     6        yes\n2               saket         Bihar     9        yes\n3            yetendra      gujarath     8        yes\n4      Kumari Shubham         Bihar     6        yes\n5           Suman Som    westbengal     7         no\n6        Soham Biswas    westbengal     7        yes\n7       Kiran Gajjana     Telangana     7         no\n8      Dorothy Barman    westbengal     7        yes\n9   Sreyashi karmakar    westbengal     7        yes\n10      Anurag Maurya  utharpradesh     7         no\n11       Bipal Khanal        Sikkim     8         no'

# %%
data1.dropna()
# Out:
#                  name          city  cgpa placemenet
# 0            Abhishek         Bihar     8        yes
# 1              Deepak        Punjab     6        yes
# 2               saket         Bihar     9        yes
# 3            yetendra      gujarath     8        yes
# 4      Kumari Shubham         Bihar     6        yes
# 5           Suman Som    westbengal     7         no
# 6        Soham Biswas    westbengal     7        yes
# 7       Kiran Gajjana     Telangana     7         no
# 8      Dorothy Barman    westbengal     7        yes
# 9   Sreyashi karmakar    westbengal     7        yes
# 10      Anurag Maurya  utharpradesh     7         no
# 11       Bipal Khanal        Sikkim     8         no

# %%
data1['city'].drop_duplicates()
# Out:
# 0            Bihar
# 1           Punjab
# 3         gujarath
# 5       westbengal
# 7        Telangana
# 10    utharpradesh
# 11          Sikkim
# Name: city, dtype: object

# %%
data1.corr()
# Out:
# <ipython-input-80-73ca661ddaf0>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data1.corr()
#       cgpa
# cgpa   1.0
